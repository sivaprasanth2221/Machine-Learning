# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('Date_Fruit_Datasets.csv')
x = data.iloc[:,:-1]
y = data['Class']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=30)
rf = RandomForestClassifier(max_depth=5,n_estimators=50)
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

# %%
print("Accuracy:",accuracy_score(y_pred,y_test))
# Out:
# Accuracy: 0.8592592592592593

# %%
tree.plot_tree(rf[0])
# Out:
# [Text(0.29583333333333334, 0.9166666666666666, 'x[16] <= 68.605\ngini = 0.831\nsamples = 402\nvalue = [39, 72, 146, 49, 102, 138, 82]'),
#  Text(0.1, 0.75, 'x[9] <= 1.377\ngini = 0.044\nsamples = 84\nvalue = [0, 0, 0, 3, 0, 130, 0]'),
#  Text(0.06666666666666667, 0.5833333333333334, 'x[11] <= 0.857\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1, 0]'),
#  Text(0.03333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.13333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 80\nvalue = [0, 0, 0, 0, 0, 129, 0]'),
#  Text(0.49166666666666664, 0.75, 'x[3] <= 390.487\ngini = 0.807\nsamples = 318\nvalue = [39, 72, 146, 46, 102, 8, 82]'),
#  Text(0.25, 0.5833333333333334, 'x[0] <= 169360.0\ngini = 0.156\nsamples = 101\nvalue = [0, 12, 141, 0, 0, 1, 0]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'x[6] <= 0.901\ngini = 0.016\nsamples = 86\nvalue = [0, 0, 127, 0, 0, 1, 0]'),
#  Text(0.13333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 85\nvalue = [0, 0, 127, 0, 0, 0, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[8] <= 0.819\ngini = 0.497\nsamples = 15\nvalue = [0, 12, 14, 0, 0, 0, 0]'),
#  Text(0.26666666666666666, 0.25, 'x[1] <= 1667.55\ngini = 0.375\nsamples = 12\nvalue = [0, 4, 12, 0, 0, 0, 0]'),
#  Text(0.23333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 10, 0, 0, 0, 0]'),
#  Text(0.3, 0.08333333333333333, 'gini = 0.444\nsamples = 4\nvalue = [0, 4, 2, 0, 0, 0, 0]'),
#  Text(0.4, 0.25, 'x[11] <= 0.781\ngini = 0.32\nsamples = 3\nvalue = [0, 8, 2, 0, 0, 0, 0]'),
#  Text(0.36666666666666664, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 5, 0, 0, 0, 0, 0]'),
#  Text(0.43333333333333335, 0.08333333333333333, 'gini = 0.48\nsamples = 2\nvalue = [0, 3, 2, 0, 0, 0, 0]'),
#  Text(0.7333333333333333, 0.5833333333333334, 'x[0] <= 333338.0\ngini = 0.79\nsamples = 217\nvalue = [39, 60, 5, 46, 102, 7, 82]'),
#  Text(0.6, 0.4166666666666667, 'x[24] <= -0.014\ngini = 0.628\nsamples = 85\nvalue = [2, 58, 5, 0, 11, 3, 63]'),
#  Text(0.5333333333333333, 0.25, 'x[12] <= 0.003\ngini = 0.471\nsamples = 41\nvalue = [0, 50, 1, 0, 10, 2, 8]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.198\nsamples = 6\nvalue = [0, 0, 0, 0, 8, 0, 1]'),
#  Text(0.5666666666666667, 0.08333333333333333, 'gini = 0.335\nsamples = 35\nvalue = [0, 50, 1, 0, 2, 2, 7]'),
#  Text(0.6666666666666666, 0.25, 'x[27] <= 3.53\ngini = 0.383\nsamples = 44\nvalue = [2, 8, 4, 0, 1, 1, 55]'),
#  Text(0.6333333333333333, 0.08333333333333333, 'gini = 0.297\nsamples = 39\nvalue = [0, 6, 4, 0, 1, 0, 54]'),
#  Text(0.7, 0.08333333333333333, 'gini = 0.722\nsamples = 5\nvalue = [2, 2, 0, 0, 0, 1, 1]'),
#  Text(0.8666666666666667, 0.4166666666666667, 'x[18] <= 96.537\ngini = 0.693\nsamples = 132\nvalue = [37, 2, 0, 46, 91, 4, 19]'),
#  Text(0.8, 0.25, 'x[1] <= 2430.786\ngini = 0.666\nsamples = 66\nvalue = [32, 0, 0, 44, 3, 4, 15]'),
#  Text(0.7666666666666667, 0.08333333333333333, 'gini = 0.667\nsamples = 42\nvalue = [30, 0, 0, 17, 3, 2, 11]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.385\nsamples = 24\nvalue = [2, 0, 0, 27, 0, 2, 4]'),
#  Text(0.9333333333333333, 0.25, 'x[11] <= 0.775\ngini = 0.236\nsamples = 66\nvalue = [5, 2, 0, 2, 88, 0, 4]'),
#  Text(0.9, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 4]'),
#  Text(0.9666666666666667, 0.08333333333333333, 'gini = 0.173\nsamples = 64\nvalue = [5, 2, 0, 2, 88, 0, 0]')]

# %%
cm=confusion_matrix(y_test,y_pred)
acc=accuracy_score(y_test,y_pred)
print("Confusion matrix : \n",cm)
print("Accuracy : ",acc)
# Out:
# Confusion matrix :
#  [[11  0  0  5  2  0  2]
#  [ 0 20  2  0  0  0 11]
#  [ 0  4 52  0  0  0  0]
#  [ 4  0  0 15  0  0  0]
#  [ 0  0  0  0 56  0  2]
#  [ 0  0  0  0  0 58  0]
#  [ 0  5  0  0  1  0 20]]
# Accuracy :  0.8592592592592593

# %%
sb.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap="hot")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
