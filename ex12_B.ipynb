# %%
import pygad
import numpy as np

# %%
function_inputs = [4,-2,3.5,5,-11,-4.7]
desired_output = 44

# %%
def fitness_func(ga_instance,solution, solution_idx):
    output = np.sum(solution*function_inputs)
    fitness = 1.0 / np.abs(output - desired_output)
    return fitness

# %%
sol_per_pop = 50
num_genes = len(function_inputs)

# %%
init_range_low = -2
init_range_high = 5

# %%
mutation_percent_genes = 1

# %%
ga_instance = pygad.GA(num_generations=2,
                       num_parents_mating=3, 
                       fitness_func=fitness_func,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       mutation_percent_genes=mutation_percent_genes)
# Out:
# /Users/sivaprasanth/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:748: UserWarning: The percentage of genes to mutate (mutation_percent_genes=1) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(f"The percentage of genes to mutate (mutation_percent_genes={mutation_percent_genes}) resutled in selecting ({mutation_num_genes}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.")

# %%
ga_instance.run()

# %%
ga_instance.plot_fitness()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
solution, solution_fitness, solution_idx = ga_instance.best_solution()

# %%
print("Best solution :",solution)
print("Fitness value of best solution :",solution_fitness)
print("Index of best solution :",solution_idx)
# Out:
# Best solution : [ 0.11490534  0.00656625 -0.70757154  3.02980143 -1.96737183 -1.9791967 ]
# Fitness value of best solution : 16.04871472395548
# Index of best solution : 0
